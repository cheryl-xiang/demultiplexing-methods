# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import math
import os

# %%
os.chdir('/Users/cherylxiang/Documents/GitHub/demultiplexing-methods/')
print(os.getcwd())
# Out:
# /Users/cherylxiang/Documents/GitHub/demultiplexing-methods

# %%
#get all summary csvs
summary_files = glob.glob('results/**/**/summary.csv', recursive=True)
summary_files = list(set(summary_files))

print(summary_files)
# Out:
# ['results/bffraw/bar18/summary.csv', 'results/gmmdemux/howitt_cell_cap2/summary.csv', 'results/demultiplex/winkler_pdx3a/summary.csv', 'results/htodemux/mcginnis_ms/summary.csv', 'results/demultiplex/winkler_pdx1b/summary.csv', 'results/hasheddrops/howitt_cell_cap1/summary.csv', 'results/gmmdemux/howitt_b1c2/summary.csv', 'results/bffraw/howitt_b1c1/summary.csv', 'results/hashsolo/winkler_pdx1d/summary.csv', 'results/demultiplex2/winkler_pdx1c/summary.csv', 'results/demultiplex2/winkler_pdx1d/summary.csv', 'results/gmmdemux/mcginnis_hto/summary.csv', 'results/demuxmix/stoeckius/summary.csv', 'results/hasheddrops/bar18/summary.csv', 'results/htodemux/ah1/summary.csv', 'results/hashsolo/cook_mix3b/summary.csv', 'results/bffcluster/cook_mix4b/summary.csv', 'results/demultiplex/howitt_cell_cap1/summary.csv', 'results/htodemux/howitt_cell_cap3/summary.csv', 'results/bffraw/cook_mix3b/summary.csv', 'results/bffcluster/winkler_pdx3b/summary.csv', 'results/bffraw/cook_mix1/summary.csv', 'results/hasheddrops/howitt_b2c2/summary.csv', 'results/demultiplex/winkler_pdx3b/summary.csv', 'results/hasheddrops/ah1/summary.csv', 'results/gmmdemux/howitt_b3c2/summary.csv', 'results/demultiplex/cook_mix4a/summary.csv', 'results/hashsolo/bar18/summary.csv', 'results/hashsolo/howitt_cell_cap2/summary.csv', 'results/bffcluster/mcginnis_ms/summary.csv', 'results/hashsolo/mcginnis_hto/summary.csv', 'results/hasheddrops/mcginnis_hto/summary.csv', 'results/demuxmixnaive/howitt_cell_cap1/summary.csv', 'results/hashsolo/cook_mix4a/summary.csv', 'results/hasheddrops/cook_mix4b/summary.csv', 'results/bffraw/winkler_pdx1c/summary.csv', 'results/hashsolo/winkler_pdx3a/summary.csv', 'results/gmmdemux/howitt_b1c1/summary.csv', 'results/hashsolo/howitt_b2c1/summary.csv', 'results/bffraw/howitt_b2c1/summary.csv', 'results/gmmdemux/mcginnis_ms/summary.csv', 'results/demultiplex2/howitt_cell_cap1/summary.csv', 'results/hashsolo/cook_mix2/summary.csv', 'results/gmmdemux/winkler_pdx1b/summary.csv', 'results/bffcluster/gaublomme/summary.csv', 'results/demultiplex/howitt_b3c2/summary.csv', 'results/demultiplex/howitt_b2c2/summary.csv', 'results/demultiplex2/bar18/summary.csv', 'results/bffraw/mcginnis_ms/summary.csv', 'results/bffraw/cook_mix4b/summary.csv', 'results/demultiplex2/cook_mix2/summary.csv', 'results/demultiplex/bar18/summary.csv', 'results/htodemux/stoeckius/summary.csv', 'results/htodemux/winkler_pdx1d/summary.csv', 'results/hashsolo/stoeckius/summary.csv', 'results/demultiplex/cook_mix4b/summary.csv', 'results/hashsolo/cook_mix3a/summary.csv', 'results/bffcluster/ah1/summary.csv', 'results/demultiplex/cook_mix2/summary.csv', 'results/hasheddrops/winkler_pdx1c/summary.csv', 'results/bffcluster/cook_mix3b/summary.csv', 'results/htodemux/bar18/summary.csv', 'results/hashsolo/winkler_pdx1c/summary.csv', 'results/demultiplex/howitt_cell_cap2/summary.csv', 'results/hasheddrops/howitt_b2c1/summary.csv', 'results/hashsolo/howitt_cell_cap3/summary.csv', 'results/hasheddrops/howitt_b3c2/summary.csv', 'results/hasheddrops/howitt_b3c1/summary.csv', 'results/bffraw/howitt_b1c2/summary.csv', 'results/demultiplex2/bar20/summary.csv', 'results/hasheddrops/howitt_b1c1/summary.csv', 'results/hasheddrops/winkler_pdx3a/summary.csv', 'results/demultiplex/cook_mix3a/summary.csv', 'results/demuxmixnaive/bar18/summary.csv', 'results/bffcluster/howitt_b2c2/summary.csv', 'results/bffcluster/winkler_pdx3a/summary.csv', 'results/demuxmixnaive/stoeckius/summary.csv', 'results/hasheddrops/cook_mix3b/summary.csv', 'results/demuxmix/gaublomme/summary.csv', 'results/demuxmixnaive/howitt_b1c1/summary.csv', 'results/hasheddrops/howitt_b1c2/summary.csv', 'results/htodemux/howitt_b3c2/summary.csv', 'results/demultiplex2/howitt_b3c1/summary.csv', 'results/hashsolo/mcginnis_ms/summary.csv', 'results/demuxmixnaive/mcginnis_hto/summary.csv', 'results/demultiplex2/mcginnis_hto/summary.csv', 'results/demultiplex/bar20/summary.csv', 'results/demultiplex/howitt_b2c1/summary.csv', 'results/bffraw/st ...

# %%
#read and combine
all_results = pd.concat([pd.read_csv(f) for f in summary_files], ignore_index=True)

#save combined dataframe
all_results.to_csv('results/all_results.csv', index=False)

all_results
# Out:
#     classification      n           dataset    method
# 0          doublet    748             bar18   bff_raw
# 1         negative   3362             bar18   bff_raw
# 2          singlet   7321             bar18   bff_raw
# 3            total  11431             bar18   bff_raw
# 4          doublet   1458  howitt_cell_cap2  gmmdemux
# ..             ...    ...               ...       ...
# 895          total   3532     winkler_pdx3a   bff_raw
# 896        doublet    683        cook_mix3a   bff_raw
# 897       negative   7244        cook_mix3a   bff_raw
# 898        singlet   5391        cook_mix3a   bff_raw
# 899          total  13318        cook_mix3a   bff_raw
#
# [900 rows x 4 columns]

# %%
plot_data = all_results[all_results['classification'] != 'total'].copy()
datasets = sorted(plot_data['dataset'].unique())

# %%
dataset_order = [
    'ah1',
    'gaublomme',
    'mcginnis_hto',
    'mcginnis_ms',
    'stoeckius',
    'cook_mix1',
    'cook_mix2',
    'cook_mix3a',
    'cook_mix3b',
    'howitt_cell_cap1',
    'howitt_cell_cap2',
    'howitt_cell_cap2',
    'howitt_b1c1',
    'howitt_b1c2',
    'howitt_b2c1',
    'howitt_b2c2',
    'howitt_b3c1',
    'howitt_b3c2',
    'winkler_pdx1a',
    'winkler_pdx1b',
    'winkler_pdx1c',
    'winkler_pdx1d',
    'winkler_pdx3a',
    'winkler_pdx3b',
    'bar18',
    'bar20'
]

method_order = [
    'demultiplex',
    'demultiplex2',
    'gmmdemux',
    'htodemux',
    'hashsolo',
    'hasheddrops',
    'bff_raw',
    'bff_cluster',
    'demuxmix',
    'demuxmix_naive',
    'demuxem'
]

# %%
colors = {
    'singlet':  "#446fac", 
    'doublet':  "#5E5E5E", 
    'negative': "#CACACA"
}

method_labels = {
    'demultiplex': 'Demultiplex',
    'demultiplex2': 'Demultiplex2',
    'htodemux': 'HTODemux',
    'hashsolo': 'HashSolo',
    'hasheddrops': 'HashedDrops',
    'bff_raw': 'BFF_Raw',
    'bff_cluster': 'BFF_Cluster',
    'gmmdemux': 'GMMDemux',
    'demuxmix': 'DemuxMix',
    'demuxmix_naive': 'DemuxMix Naive',
    'cmddemux': 'CMDdemux',
    'demuxem' : 'DemuxEM'
}

dataset_labels = {
    'ah1' : 'Ji_Bar11',
    'gaublomme': 'Gaublomme',
    'mcginnis_hto': 'McGinnis_HTO',
    'mcginnis_ms': 'McGinnis_MS',
    'stoeckius': 'Stoeckius',
    'cook_mix1' : 'Cook_Mix1',
    'cook_mix2' : 'Cook_Mix2',
    'cook_mix3a' : 'Cook_Mix3a',
    'cook_mix3b' : 'Cook_Mix3b',
    'cook_mix4a' : 'Cook_Mix4a',
    'cook_mix4b' : 'Cook_Mix4b',
    'howitt_cell_cap1' : 'Howitt_Cap1',
    'howitt_cell_cap2' : 'Howitt_Cap2',
    'howitt_cell_cap3' : 'Howitt_Cap3',
    'howitt_b1c1' : 'Howitt_Batch1_C1',
    'howitt_b1c2' : 'Howitt_Batch1_C2',
    'howitt_b2c1' : 'Howitt_Batch2_C1',
    'howitt_b2c2' : 'Howitt_Batch2_C2',
    'howitt_b3c1' : 'Howitt_Batch3_C1',
    'howitt_b3c2' : 'Howitt_Batch3_C2',
    'winkler_pdx1a': 'Winkler_PDX1a',
    'winkler_pdx1b': 'Winkler_PDX1b',
    'winkler_pdx1c': 'Winkler_PDX1c',
    'winkler_pdx1d': 'Winkler_PDX1d',
    'winkler_pdx3a': 'Winkler_PDX3a',
    'winkler_pdx3b': 'Winkler_PDX3b',
    'bar18' : 'Bar18',
    'bar20' : 'Bar20'
}

# %%
for dataset in datasets:
    dataset_data = plot_data[plot_data['dataset'] == dataset].copy()
    dataset_data['proportion'] = dataset_data.groupby('method')['n'].transform(lambda x: x / x.sum())

    pivot = dataset_data.pivot_table(
        index='method',
        columns='classification',
        values='proportion',
        fill_value=0
    )

    # add failed methods as all negative
    for method in method_order:
        if method not in pivot.index:
            pivot.loc[method] = 0
            if 'negative' in pivot.columns:
                pivot.loc[method, 'negative'] = 1.0
            else:
                pivot['negative'] = 0
                pivot.loc[method, 'negative'] = 1.0

    # apply custom method order, only include methods present in pivot
    ordered_methods = [m for m in method_order if m in pivot.index]
    pivot = pivot.loc[ordered_methods]

    col_order = [c for c in ['singlet', 'doublet', 'negative'] if c in pivot.columns]
    pivot = pivot[col_order]

    fig, ax = plt.subplots(figsize=(6, 4))
    bottom = pd.Series([0] * len(pivot), index=pivot.index)

    for classification in col_order:
        bars = ax.bar(pivot.index, pivot[classification],
                  bottom=bottom,
                  label=classification,
                  color=colors[classification])
        bottom += pivot[classification]

    ax.set_ylabel('Proportion', fontsize=14)
    ax.set_title(dataset_labels.get(dataset, dataset), fontsize=18)
    ax.set_ylim(0, 1)
    ax.legend(title='Classification')
    ax.set_xticks(range(len(pivot.index)))
    ax.set_xticklabels([method_labels.get(m, m) for m in pivot.index], rotation=45, ha='right', fontsize=15)
    plt.yticks(fontsize=14)
    plt.tight_layout()

    os.makedirs(f'analysis/figures/{dataset}', exist_ok=True)
    plt.savefig(f'analysis/figures/{dataset}/stacked_bar.pdf')
    plt.show()

# %%
n_datasets = len(dataset_order)
n_cols = 6
n_rows = math.ceil(n_datasets / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 6, n_rows * 4))
axes = axes.flatten()

for i, dataset in enumerate(dataset_order):
    ax = axes[i]
    dataset_data = plot_data[plot_data['dataset'] == dataset].copy()
    dataset_data['proportion'] = dataset_data.groupby('method')['n'].transform(lambda x: x / x.sum())

    pivot = dataset_data.pivot_table(
        index='method',
        columns='classification',
        values='proportion',
        fill_value=0
    )

    # add missing methods as all negative
    for method in method_order:
        if method not in pivot.index:
            pivot.loc[method] = 0
            if 'negative' in pivot.columns:
                pivot.loc[method, 'negative'] = 1.0
            else:
                pivot['negative'] = 0
                pivot.loc[method, 'negative'] = 1.0

    ordered_methods = [m for m in method_order if m in pivot.index]
    pivot = pivot.loc[ordered_methods]

    col_order = [c for c in ['singlet', 'doublet', 'negative'] if c in pivot.columns]
    pivot = pivot[col_order]

    bottom = pd.Series([0] * len(pivot), index=pivot.index)
    for classification in col_order:
        ax.bar(pivot.index, pivot[classification],
               bottom=bottom,
               label=classification,
               color=colors[classification])
        bottom += pivot[classification]

    ax.set_title(dataset_labels.get(dataset, dataset), fontsize=18)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(len(pivot.index)))
    ax.set_xticklabels([method_labels.get(m, m) for m in pivot.index], rotation=45, ha='right', fontsize=17)
    ax.tick_params(axis='y', labelsize=16)

# hide unused axes
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

# single shared legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower right', fontsize=22)
fig.supylabel('Proportion', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(right=0.1)

plt.tight_layout()
os.makedirs('analysis/figures', exist_ok=True)
plt.savefig('analysis/figures/all_datasets.pdf')
plt.show()
